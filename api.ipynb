# %%
import requests 
import sqlite3 as sql                 
import pandas as pd
conn = sql.connect('App.db')
cursor = conn.cursor()

# %%
url = 'https://api.data.gov.sg/v1/environment/air-temperature'
response = requests.get(url)
if response.status_code != 200:
    raise Exception("Api Fora")
data = response.json()     
data
# Out:
# {'metadata': {'stations': [{'id': 'S107',
#     'device_id': 'S107',
#     'name': 'East Coast Parkway',
#     'location': {'latitude': 1.3135, 'longitude': 103.9625}},
#    {'id': 'S24',
#     'device_id': 'S24',
#     'name': 'Upper Changi Road North',
#     'location': {'latitude': 1.3678, 'longitude': 103.9826}},
#    {'id': 'S104',
#     'device_id': 'S104',
#     'name': 'Woodlands Avenue 9',
#     'location': {'latitude': 1.44387, 'longitude': 103.78538}}],
#   'reading_type': 'DBT 1M F',
#   'reading_unit': 'deg C'},
#  'items': [{'timestamp': '2026-01-20T09:55:00+08:00',
#    'readings': [{'station_id': 'S107', 'value': 26.9},
#     {'station_id': 'S24', 'value': 27},
#     {'station_id': 'S104', 'value': 26.8}]}],
#  'api_info': {'status': 'healthy'}}
